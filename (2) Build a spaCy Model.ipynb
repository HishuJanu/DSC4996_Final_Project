# %%
# !pip install spacy -U
# !pip install spacy-transformers
# !python -m spacy download en_core_web_lg
# !pip install pyproject.toml-based
# !pip install CuPy

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.7.2
# Location         /usr/local/lib/python3.10/dist-packages/spacy
# Platform         Linux-6.1.58+-x86_64-with-glibc2.35
# Python version   3.10.12
# Pipelines        en_core_web_lg (3.7.1), en_core_web_sm (3.7.1)

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import json

# %%
nlp = spacy.blank("en")

# %%
f = open('/content/drive/MyDrive/4th_Year/DSC4996/Spacy/train_data.json')
train_data = json.load(f)
train_data
# Out:
# {'classes': ['POLICY_NO',
#   'DATE',
#   'DOCTOR',
#   'HOSPITAL',
#   'AMOUNT',
#   'ADDITIONAL ACCIDENT COVER',
#   'ADDITIONAL CRITICAL ILLNESS COVER',
#   'CASHLESS HOSPITAL COVER',
#   'CRITICAL ILLNESS COVER',
#   'FAMILY INCOME BEENEFIT',
#   'FUNERAL EXPENSES',
#   'PERSONAL ACCIDENT COVER'],
#  'annotations': [["jxg janashakthi group claims action sheet policy number: nju32014-182 date: 22-02-2023 doctor name: dr anomila hospital name: new pioneer hospital description of accident: patient fell while climbing stairs at home, fracturing their wrist. description of claim: hospital room and board charges for 2 days of inpatient stay, surgeon's fees for wrist fracture repair, anesthesia costs during surgery, direct settlement of eligible medical expenses with the hospital, without upfront payment by the patient. amount (rs.): 20000",
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 110, 'DOCTOR'],
#      [126, 146, 'HOSPITAL'],
#      [519, 524, 'AMOUNT'],
#      [262, 275, 'CASHLESS HOSPITAL COVER'],
#      [280, 293, 'CASHLESS HOSPITAL COVER'],
#      [308, 322, 'CASHLESS HOSPITAL COVER'],
#      [324, 338, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [366, 382, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [429, 445, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: nju32014-274 date: 03-04-2022 doctor name: dr jayasundara hospital name: dgh polonnaruwa description of accident: severe injury from a motor vehicle accident leading to critical illness description of claim: used for initial ambulance and emergency room expenses, medical expenses related to the accident, as well as temporary disability benefits due to the inability to work during recovery. amount (rs.): 8000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 114, 'DOCTOR'],
#      [130, 145, 'HOSPITAL'],
#      [464, 468, 'AMOUNT'],
#      [282, 291, 'PERSONAL ACCIDENT COVER'],
#      [296, 319, 'CASHLESS HOSPITAL COVER'],
#      [321, 337, 'CASHLESS HOSPITAL COVER'],
#      [374, 403, 'PERSONAL ACCIDENT COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: nsw2125155 date: 16-02-2023 doctor name: dr.wijewardana hospital name: royal hospital description of accident: death of policyholder due to accidental drowning description of claim: claim for payment of final medical expenses incurred during emergency care and resuscitation efforts following the accidental drowning, and monthly income replacement to support the family's financial needs following the policyholder's death. amount (rs.): 10000",
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 112, 'DOCTOR'],
#      [128, 142, 'HOSPITAL'],
#      [496, 501, 'AMOUNT'],
#      [266, 282, 'CASHLESS HOSPITAL COVER'],
#      [299, 313, 'CASHLESS HOSPITAL COVER'],
#      [379, 405, 'FAMILY INCOME BENEFIT']]}],
#   ["jxg janashakthi group claims action sheet policy number: lif1234052 date: 08-09-2023 doctor name: dr.manjula hospital name: royal hospital description of accident: acute appendicitis description of claim: claims for initial emergency room consultation, diagnostic tests (blood tests, ultrasound), pre-operative expenses, hospital room and board charges, surgeon's fees, anesthesia costs, medications and consumables, post-operative care and nursing amount (rs.): 3000",
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 108, 'DOCTOR'],
#      [124, 138, 'HOSPITAL'],
#      [463, 467, 'AMOUNT'],
#      [224, 251, 'CASHLESS HOSPITAL COVER'],
#      [253, 269, 'CASHLESS HOSPITAL COVER'],
#      [271, 282, 'CASHLESS HOSPITAL COVER'],
#      [297, 319, 'CASHLESS HOSPITAL COVER'],
#      [321, 334, 'CASHLESS HOSPITAL COVER'],
#      [339, 352, 'CASHLESS HOSPITAL COVER'],
#      [354, 368, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [370, 386, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [388, 399, 'CASHLESS HOSPITAL COVER'],
#      [404, 415, 'CASHLESS HOSPITAL COVER'],
#      [417, 436, 'CASHLESS HOSPITAL COVER'],
#      [441, 448, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: jlu2007-1501 date: 03-04-2022 doctor name: dr.manjula hospital name: asiri hospital description of accident: accidental fall leading to critical illness and complex recovery description of claim: ambulance transport and emergency room expenses, admitted to icu for 10 days, requiring multiple surgeries and intensive care, hospital stay, surgery costs, icu charges, diagnosed with traumatic brain injury (tbi) and partial paralysis, claiming lump-sum disability benefit for partial paralysis as a result of the stroke, as per policy terms. amount (rs.): 6500',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 110, 'DOCTOR'],
#      [126, 140, 'HOSPITAL'],
#      [611, 615, 'AMOUNT'],
#      [253, 272, 'PERSONAL ACCIDENT COVER'],
#      [277, 300, 'CASHLESS HOSPITAL COVER'],
#      [380, 393, 'CASHLESS HOSPITAL COVER'],
#      [395, 408, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [410, 421, 'CASHLESS HOSPITAL COVER'],
#      [438, 466, 'CRITICAL ILLNESS COVER'],
#      [471, 488, 'CRITICAL ILLNESS COVER'],
#      [508, 526, 'PERSONAL ACCIDENT COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012125518 date: 01-04-2022 doctor name: dr.upul hospital name: pgh badulla description of accident: loss of vision due to diabetes description of claim: lump-sum payment for vision-related aids and care. amount (rs.): 12350',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 107, 'DOCTOR'],
#      [123, 134, 'HOSPITAL'],
#      [278, 283, 'AMOUNT'],
#      [234, 262, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01222410 date: 30-03-2023 doctor name: dr.wasanthi hospital name: nawaloka hospital description of accident: high-speed collision resulting in a traumatic brain injury description of claim: ambulance charges, emergency room care, initial x-rays and ct scans, lump-sum payment for home modifications and long-term care needs. amount (rs.): 800000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 143, 'HOSPITAL'],
#      [399, 405, 'AMOUNT'],
#      [250, 267, 'PERSONAL ACCIDENT COVER'],
#      [269, 288, 'CASHLESS HOSPITAL COVER'],
#      [290, 304, 'CASHLESS HOSPITAL COVER'],
#      [309, 317, 'CASHLESS HOSPITAL COVER'],
#      [340, 358, 'PERSONAL ACCIDENT COVER'],
#      [363, 377, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01226811 date: 21-11-2022 doctor name: dr.rajitha hospital name: pgh badulla description of accident: patient falls from a ladder while working on their house, resulting in spinal cord injury and paralysis. description of claim: covers medical expenses for emergency care, surgery, rehabilitation, and assistive devices, as well as disability benefits to replace lost income, lump-sum payment to assist with long-term care costs, home modifications, and lifestyle adjustments. amount (rs.): 21000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 136, 'HOSPITAL'],
#      [551, 556, 'AMOUNT'],
#      [296, 312, 'CASHLESS HOSPITAL COVER'],
#      [317, 331, 'CASHLESS HOSPITAL COVER'],
#      [333, 340, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [342, 356, 'CRITICAL ILLNESS COVER'],
#      [362, 379, 'CRITICAL ILLNESS COVER'],
#      [392, 411, 'PERSONAL ACCIDENT COVER'],
#      [415, 434, 'FAMILY INCOME BENEFIT'],
#      [468, 488, 'CRITICAL ILLNESS COVER'],
#      [490, 508, 'PERSONAL ACCIDENT COVER'],
#      [514, 535, 'PERSONAL ACCIDENT COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt0123702 date: 02-06-2023 doctor name: dr.thevarajh hospital name: nh colombo description of accident: fracture surgery description of claim: direct settlement of surgical fees, operating room expenses, anesthesia costs, and post-operative care, including physiotherapy. amount (rs.): 16500',
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 110, 'DOCTOR'],
#      [126, 136, 'HOSPITAL'],
#      [344, 349, 'AMOUNT'],
#      [222, 235, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [237, 260, 'CASHLESS HOSPITAL COVER'],
#      [262, 278, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [284, 303, 'CASHLESS HOSPITAL COVER'],
#      [315, 328, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01228111 date: 05-03-2023 doctor name: dr. sudeera hospital name: bh kahawatte description of accident: patient sustains a severe head injury in a car crash, resulting in cognitive and physical impairments description of claim: covers medical expenses for emergency care, neurosurgical procedures, extensive rehabilitation, and ongoing medical management, as well as disability benefits, lump-sum payment to assist with long-term care costs, home modifications, assistive devices, and potential caregiver expenses. amount (rs.): 9550',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 138, 'HOSPITAL'],
#      [589, 593, 'AMOUNT'],
#      [295, 311, 'CASHLESS HOSPITAL COVER'],
#      [316, 330, 'CASHLESS HOSPITAL COVER'],
#      [332, 356, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [358, 382, 'CRITICAL ILLNESS COVER'],
#      [388, 414, 'CRITICAL ILLNESS COVER'],
#      [427, 446, 'PERSONAL ACCIDENT COVER'],
#      [480, 500, 'CRITICAL ILLNESS COVER'],
#      [502, 520, 'PERSONAL ACCIDENT COVER'],
#      [522, 539, 'CRITICAL ILLNESS COVER'],
#      [545, 573, 'FAMILY INCOME BENEFIT']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt0122164 date: 29-06-2022 doctor name: dr.sugathadasa hospital name: ayurvedic hospital narammala description of accident: heart attack and bypass surgery description of claim: diagnostic tests like ecg and blood tests, emergency room admission, initial medications to stabilize the condition,lump-sum payment for lifestyle changes like cardiac rehab and stress management programs amount (rs.): 10500',
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 112, 'DOCTOR'],
#      [128, 156, 'HOSPITAL'],
#      [455, 460, 'AMOUNT'],
#      [236, 252, 'CASHLESS HOSPITAL COVER'],
#      [279, 303, 'CASHLESS HOSPITAL COVER'],
#      [421, 440, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012219819 date: 28-06-2023 doctor name: dr.prasad hospital name: bh tangalle description of accident: childbirth description of claim: patient delivers a baby at a hospital via normal delivery. claim for covers prenatal checkups and delivery charges, labor room expenses, newborn care, and 3-day hospital stay for mother and baby. amount (rs.): 23000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 109, 'DOCTOR'],
#      [125, 136, 'HOSPITAL'],
#      [405, 410, 'AMOUNT'],
#      [271, 288, 'CRITICAL ILLNESS COVER'],
#      [293, 309, 'CRITICAL ILLNESS COVER'],
#      [311, 330, 'CASHLESS HOSPITAL COVER'],
#      [332, 344, 'FAMILY INCOME BENEFIT'],
#      [350, 369, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: nsw2112749 date: 05-05-2023 doctor name: dr senadhira hospital name: dgh polonnaruwa description of accident: emergency appendectomy description of claim: patient wants to covers surgery costs, medication, room charges, direct payment to the hospital, and no out-of-pocket expenses amount (rs.): 2500000',
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 110, 'DOCTOR'],
#      [126, 141, 'HOSPITAL'],
#      [353, 360, 'AMOUNT'],
#      [236, 249, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [251, 261, 'CASHLESS HOSPITAL COVER'],
#      [263, 275, 'CASHLESS HOSPITAL COVER'],
#      [277, 307, 'CASHLESS HOSPITAL COVER'],
#      [313, 338, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012018-1905 date: 01-05-2023 doctor name: dr.lakmini hospital name: dgh polonnaruwa description of accident: allergic reaction treatment description of claim: patient claims cover for antihistamines, epinephrine injection, and observation in the emergency room for an allergic reaction. amount (rs.): 50000',
#    {'entities': [[57, 71, 'POLICY_NO'],
#      [78, 88, 'DATE'],
#      [102, 112, 'DOCTOR'],
#      [128, 143, 'HOSPITAL'],
#      [361, 366, 'AMOUNT'],
#      [244, 258, 'CASHLESS HOSPITAL COVER'],
#      [260, 281, 'CASHLESS HOSPITAL COVER'],
#      [306, 320, 'CASHLESS HOSPITAL COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt01231923 date: 04-07-2023 doctor name: dr duminda hospital name: bh homagama description of accident: fell off a ladder while painting the house description of claim: i am seeking reimbursement through my covers for the er visit, x-rays, orthopedic consultations, and pain medication. additionally, i'm filing a claim under my additional cover for ambulance transportation to the hospital, physiotherapy sessions, and a portion of my lost income due to temporary disability. amount (rs.): 35000",
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 136, 'HOSPITAL'],
#      [549, 554, 'AMOUNT'],
#      [280, 288, 'CASHLESS HOSPITAL COVER'],
#      [290, 296, 'CASHLESS HOSPITAL COVER'],
#      [298, 322, 'CASHLESS HOSPITAL COVER'],
#      [328, 343, 'CASHLESS HOSPITAL COVER'],
#      [408, 432, 'PERSONAL ACCIDENT COVER'],
#      [450, 472, 'CASHLESS HOSPITAL COVER'],
#      [494, 505, 'FAMILY INCOME BENEFIT']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01214981 date: 08-08-2023 doctor name: dr duminda hospital name: nawaloka hospital description of accident: cancer treatment and hospitalization description of claim: multiple inpatient stays for treatment cycles, specialist consultations with oncologists and radiotherapists, and pain management medications amount (rs.): 19550',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 142, 'HOSPITAL'],
#      [383, 388, 'AMOUNT'],
#      [227, 251, 'CASHLESS HOSPITAL COVER'],
#      [274, 298, 'CRITICAL ILLNESS COVER'],
#      [341, 356, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012121947 date: 28-05-2023 doctor name: dr.kenneth hospital name: asiri hospital description of accident: fractured leg surgery description of claim: surgery to repair a fractured leg, including implants, anesthesia, and hospital stay. amount (rs.): 50000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 110, 'DOCTOR'],
#      [126, 140, 'HOSPITAL'],
#      [310, 315, 'AMOUNT'],
#      [180, 187, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [255, 263, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [265, 275, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [281, 294, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012125168 date: 25-05-2023 doctor name: dr.ruvan hospital name: pgh badulla description of accident: dog bite treatment description of claim: patient claims his cover for emergency room visit, stitches, rabies vaccination, and antibiotics for a dog bite. amount (rs.): 8700',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 135, 'HOSPITAL'],
#      [329, 333, 'AMOUNT'],
#      [231, 251, 'CASHLESS HOSPITAL COVER'],
#      [253, 261, 'CASHLESS HOSPITAL COVER'],
#      [263, 281, 'PERSONAL ACCIDENT COVER'],
#      [287, 298, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: nsw2123165 date: 09-12-2021 doctor name: dr.manjula hospital name: bh mawanella description of accident: while cycling to work, the insured individual was struck by a car, resulting in multiple fractures to their right leg and arm description of claim: ambulance transportation to the hospital, emergency room treatment, including x-rays and initial casting, hospital stay for 3 days, orthopedic surgeon consultation, surgical repair of fractures, physical therapy sessions amount (rs.): 21000',
#    {'entities': [[57, 67, 'POLICY_NO'],
#      [74, 84, 'DATE'],
#      [98, 108, 'DOCTOR'],
#      [124, 136, 'HOSPITAL'],
#      [545, 550, 'AMOUNT'],
#      [310, 334, 'PERSONAL ACCIDENT COVER'],
#      [352, 376, 'CASHLESS HOSPITAL COVER'],
#      [388, 394, 'CASHLESS HOSPITAL COVER'],
#      [399, 414, 'CASHLESS HOSPITAL COVER'],
#      [416, 429, 'CASHLESS HOSPITAL COVER'],
#      [442, 473, 'CASHLESS HOSPITAL COVER'],
#      [475, 490, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [505, 530, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01222289 date: 13-07-2022 doctor name: dr.chathura hospital name: dgh nuwaraeliya description of accident: involved in a car accident description of claim: claim for all hospitalization expenses, including surgery, medications, room charges, and other necessary medical services, directly settled with the hospital, claim for income replacement benefits due to inability to work during recovery. amount (rs.): 30000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 141, 'HOSPITAL'],
#      [470, 475, 'AMOUNT'],
#      [266, 273, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [275, 286, 'CASHLESS HOSPITAL COVER'],
#      [288, 300, 'CASHLESS HOSPITAL COVER'],
#      [306, 338, 'CASHLESS HOSPITAL COVER'],
#      [386, 413, 'FAMILY INCOME BENEFIT']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01222259 date: 01-06-2022 doctor name: dr.priyantha hospital name: sethma hospital description of accident: diagnosis of lung cancer description of claim: policy holder wants to claim amout for initial consultations, diagnostic tests, chemotherapy, radiation therapy, and targeted therapy amount (rs.): 350000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 111, 'DOCTOR'],
#      [127, 142, 'HOSPITAL'],
#      [363, 369, 'AMOUNT'],
#      [254, 275, 'CASHLESS HOSPITAL COVER'],
#      [277, 293, 'CASHLESS HOSPITAL COVER'],
#      [295, 307, 'CRITICAL ILLNESS COVER'],
#      [309, 326, 'CRITICAL ILLNESS COVER'],
#      [332, 348, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01224046 date: 02-04-2022 doctor name: dr.prasad hospital name: bh hingurakgoda description of accident: fractured arm description of claim: patient admitted with excruciating pain and restricted arm movement after a fall. x-rays revealed a fractured radius, requiring surgical repair.he want to pay x-rays, pain relief medication, facilitates surgery, hospital stay, and post-operative care charges to ensuring a smooth recovery process amount (rs.): 200000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 108, 'DOCTOR'],
#      [124, 139, 'HOSPITAL'],
#      [512, 518, 'AMOUNT'],
#      [283, 289, 'CASHLESS HOSPITAL COVER'],
#      [368, 390, 'CASHLESS HOSPITAL COVER'],
#      [392, 411, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [413, 426, 'CASHLESS HOSPITAL COVER'],
#      [432, 451, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: jca01224286 date: 09-11-2022 doctor name: dr bandula hospital name: durdans hospital description of accident: patient suffers extensive burns in a house fire caused by a faulty electrical appliance description of claim: claiming medical expenses for emergency care, burn treatment, multiple surgeries, and skin grafts, as well as psychological counseling for trauma, lump-sum payment to assist with long-term care costs, specialized clothing and equipment, and potential home modifications. amount (rs.): 25000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 141, 'HOSPITAL'],
#      [562, 567, 'AMOUNT'],
#      [286, 302, 'CASHLESS HOSPITAL COVER'],
#      [323, 337, 'CRITICAL ILLNESS COVER'],
#      [339, 357, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [363, 374, 'CRITICAL ILLNESS COVER'],
#      [387, 411, 'CRITICAL ILLNESS COVER'],
#      [456, 476, 'CRITICAL ILLNESS COVER'],
#      [478, 512, 'CRITICAL ILLNESS COVER'],
#      [518, 546, 'PERSONAL ACCIDENT COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01223919 date: 26-04-2023 doctor name: dr bandula hospital name: durdans hospital description of accident: appendectomy description of claim: claims cover for laparoscopic appendectomy surgery, hospital stay, and post-operative medications. amount (rs.): 7800',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 141, 'HOSPITAL'],
#      [315, 319, 'AMOUNT'],
#      [219, 252, 'CASHLESS HOSPITAL COVER'],
#      [254, 267, 'CASHLESS HOSPITAL COVER'],
#      [273, 299, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: jca01226993 date: 03-12-2022 doctor name: dr champika hospital name: lanka hospital description of accident: spinal cord injury from a sports accident description of claim: additional accident cover: emergency room care, x-rays, mris, surgery or spinal stabilization procedures, physical therapy, occupational therapy, wheelchair, adaptive equipment, income replacement benefits, extended hospital stay, specialist consultations with neurologists and orthopedic surgeons, intensive rehabilitation services, pain management medications. amount (rs.): 550000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 140, 'HOSPITAL'],
#      [607, 613, 'AMOUNT'],
#      [257, 276, 'CASHLESS HOSPITAL COVER'],
#      [278, 284, 'CASHLESS HOSPITAL COVER'],
#      [286, 290, 'CASHLESS HOSPITAL COVER'],
#      [292, 299, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [303, 334, 'CRITICAL ILLNESS COVER'],
#      [336, 352, 'CASHLESS HOSPITAL COVER'],
#      [354, 374, 'CASHLESS HOSPITAL COVER'],
#      [376, 386, 'CASHLESS HOSPITAL COVER'],
#      [408, 435, 'FAMILY INCOME BENEFIT'],
#      [446, 459, 'CASHLESS HOSPITAL COVER'],
#      [461, 485, 'CRITICAL ILLNESS COVER'],
#      [491, 527, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [529, 562, 'CRITICAL ILLNESS COVER'],
#      [564, 591, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01222677 date: 19-06-2023 doctor name: dr.duleeka hospital name: dgh nuwaraeliya description of accident: dengue fever hospitalization description of claim: patient claims cover for 5-day hospitalization due to dengue fever, including room charges, iv fluids, and medication. amount (rs.): 12000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 140, 'HOSPITAL'],
#      [350, 355, 'AMOUNT'],
#      [295, 307, 'CASHLESS HOSPITAL COVER'],
#      [309, 318, 'CASHLESS HOSPITAL COVER'],
#      [324, 334, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01226112 date: 27-06-2023 doctor name: dr deeptha hospital name: dgh hambanthota description of accident: stage ii breast cancer description of claim: i am utilizing my coverages to reimburse the costs of my lumpectomy, chemotherapy sessions, radiation treatments, oncology consultations, and related hospitalization expenses. additionally, i am filing to claim more coverages for diagnostic tests, medications, and follow-up appointments. amount (rs.): 20500',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 140, 'HOSPITAL'],
#      [514, 519, 'AMOUNT'],
#      [268, 278, 'CRITICAL ILLNESS COVER'],
#      [280, 301, 'CRITICAL ILLNESS COVER'],
#      [303, 323, 'CRITICAL ILLNESS COVER'],
#      [325, 347, 'CRITICAL ILLNESS COVER'],
#      [353, 385, 'CASHLESS HOSPITAL COVER'],
#      [441, 457, 'CASHLESS HOSPITAL COVER'],
#      [459, 470, 'CASHLESS HOSPITAL COVER'],
#      [476, 498, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012210997 date: 06-03-2023 doctor name: dr.pahalagamage hospital name: dh angoda description of accident: machinery malfunction causing significant leg injury requiring amputation description of claim: medical expenses for wound care, rehabilitation, and psychological counseling related to the trauma, post-operative care, physical therapy to learn to use the prosthetic, and prosthetic fitting and training amount (rs.): 19750',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 115, 'DOCTOR'],
#      [131, 140, 'HOSPITAL'],
#      [483, 488, 'AMOUNT'],
#      [262, 278, 'CASHLESS HOSPITAL COVER'],
#      [295, 309, 'CRITICAL ILLNESS COVER'],
#      [315, 339, 'CRITICAL ILLNESS COVER'],
#      [363, 382, 'CASHLESS HOSPITAL COVER'],
#      [384, 400, 'CASHLESS HOSPITAL COVER'],
#      [437, 468, 'CRITICAL ILLNESS COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt01228803 date: 10-08-2022 doctor name: dr.sanjeewa hospital name: apeksha hospital description of accident: 3-day hospitalization for severe food poisoning description of claim: ambulance fees, emergency room care, diagnostic tests (ct scans, mris), surgery costs, neurologist consultations, post-operative medications, cognitive rehabilitation therapy, intensive care unit (icu) stay, neurosurgeon's fees, medication costs, physiotherapy and occupational therapy services during hospitalization. amount (rs.): 18500",
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 142, 'HOSPITAL'],
#      [571, 576, 'AMOUNT'],
#      [238, 252, 'PERSONAL ACCIDENT COVER'],
#      [254, 273, 'CASHLESS HOSPITAL COVER'],
#      [275, 291, 'CASHLESS HOSPITAL COVER'],
#      [293, 301, 'CASHLESS HOSPITAL COVER'],
#      [303, 307, 'CASHLESS HOSPITAL COVER'],
#      [310, 323, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [325, 350, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [352, 378, 'CASHLESS HOSPITAL COVER'],
#      [380, 412, 'CRITICAL ILLNESS COVER'],
#      [414, 433, 'CASHLESS HOSPITAL COVER'],
#      [435, 438, 'CASHLESS HOSPITAL COVER'],
#      [446, 465, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [467, 483, 'CASHLESS HOSPITAL COVER'],
#      [485, 498, 'CASHLESS HOSPITAL COVER'],
#      [503, 523, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012211206 date: 21-11-2022 doctor name: dr.wathudura hospital name: asiri hospital description of accident: my father-in-law suffernig from heart attack and he requiring angioplasty and stent placement description of claim: as a policy holder i request to collect a required money to pay ambulance fees, initial er treatment, angioplasty procedure, stents, hospital stay, direct payment to the hospital, and no upfront costs amount (rs.): 13600',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 112, 'DOCTOR'],
#      [128, 142, 'HOSPITAL'],
#      [499, 504, 'AMOUNT'],
#      [348, 362, 'PERSONAL ACCIDENT COVER'],
#      [364, 384, 'CASHLESS HOSPITAL COVER'],
#      [386, 407, 'CASHLESS HOSPITAL COVER'],
#      [409, 415, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [417, 430, 'CASHLESS HOSPITAL COVER'],
#      [432, 462, 'CASHLESS HOSPITAL COVER'],
#      [471, 484, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012210693 date: 14-02-2023 doctor name: dr.upali hospital name: new lanka maternity hospital description of accident: childbirth with complications description of claim: prenatal consultations and ultrasounds, epidural anesthesia during labor, post-natal care for mother and baby, emergency c-section due to fetal distress, extended hospital stay for mother and baby, neonatal intensive care unit (nicu) stay for newborn, if needed. amount (rs.): 14000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 152, 'HOSPITAL'],
#      [507, 512, 'AMOUNT'],
#      [230, 252, 'CRITICAL ILLNESS COVER'],
#      [257, 268, 'CRITICAL ILLNESS COVER'],
#      [270, 289, 'CRITICAL ILLNESS COVER'],
#      [304, 319, 'CRITICAL ILLNESS COVER'],
#      [341, 360, 'CRITICAL ILLNESS COVER'],
#      [384, 406, 'CASHLESS HOSPITAL COVER'],
#      [428, 456, 'CASHLESS HOSPITAL COVER'],
#      [458, 462, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012213239 date: 25-09-2022 doctor name: dr.hemal hospital name: dh dambadeniya description of accident: house fire resulting in second-degree burns on arms and torso description of claim: medical expenses for burn treatments, multiple surgeries for skin grafts, and psychological counseling for burns-related trauma, extensive hospitalization including specialized burn unit care, pain management medications, and physical therapy to regain mobility amount (rs.): 15300',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 138, 'HOSPITAL'],
#      [524, 529, 'AMOUNT'],
#      [269, 284, 'CRITICAL ILLNESS COVER'],
#      [286, 304, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [326, 350, 'CRITICAL ILLNESS COVER'],
#      [377, 402, 'CASHLESS HOSPITAL COVER'],
#      [413, 439, 'CRITICAL ILLNESS COVER'],
#      [441, 468, 'CRITICAL ILLNESS COVER'],
#      [474, 490, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012214037 date: 02-01-2023 doctor name: dr.aruna hospital name: asiri hospital description of accident: sustained multiple injuries, including a fractured pelvis and internal bleeding, in a motor vehicle collision. description of claim: accommodation in an intensive care unit (icu) for 7 days, surgical fees for exploratory laparotomy and pelvic fracture repair, professional fees, costs of trauma surgeon, orthopedic surgeon, intensivist, post-operative rehabilitation services, including physiotherapy and occupational therapy. amount (rs.): 23500',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 138, 'HOSPITAL'],
#      [605, 610, 'AMOUNT'],
#      [317, 336, 'CASHLESS HOSPITAL COVER'],
#      [338, 341, 'CASHLESS HOSPITAL COVER'],
#      [355, 368, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [400, 422, 'CASHLESS HOSPITAL COVER'],
#      [452, 466, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [468, 486, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [488, 499, 'CASHLESS HOSPITAL COVER'],
#      [501, 539, 'CASHLESS HOSPITAL COVER'],
#      [551, 564, 'CASHLESS HOSPITAL COVER'],
#      [569, 589, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012212853 date: 09-01-2023 doctor name: dr.aruna hospital name: golden key hospital description of accident: cancer treatment and hospitalization description of claim: initial consultations with oncologists, biopsies, and diagnostic procedures to determine stage and type of cancer, multiple inpatient stays for treatment cycles, specialist consultations with oncologists and radiotherapists, and pain management medications amount (rs.): 18000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 143, 'HOSPITAL'],
#      [499, 504, 'AMOUNT'],
#      [228, 249, 'CASHLESS HOSPITAL COVER'],
#      [255, 266, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [268, 276, 'CRITICAL ILLNESS COVER'],
#      [282, 303, 'CASHLESS HOSPITAL COVER'],
#      [343, 367, 'CASHLESS HOSPITAL COVER'],
#      [390, 414, 'CRITICAL ILLNESS COVER'],
#      [436, 451, 'CRITICAL ILLNESS COVER'],
#      [457, 484, 'CRITICAL ILLNESS COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt012212920 date: 03-03-2023 doctor name: dr.sherman hospital name: sethma hospital description of accident: x-ray for ankle sprain description of claim: policy holder twisted their ankle playing sports and experiences swelling and pain. he visit a doctor who orders an x-ray to rule out fractures. now he wants to claim the insurance payment for x-ray cost and doctor's consultation fee. amount (rs.): 17550",
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 110, 'DOCTOR'],
#      [126, 141, 'HOSPITAL'],
#      [461, 466, 'AMOUNT'],
#      [405, 415, 'CASHLESS HOSPITAL COVER'],
#      [420, 445, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012214891 date: 11-01-2023 doctor name: dr.ratnayake hospital name: bh mahiyanganaya description of accident: kidney failure and dialysis description of claim: lump-sum payment to manage dietary restrictions, lifestyle changes like dialysis equipment installation at home, and ongoing medications, regular dialysis sessions in a clinic or at home, hospitalizations for complications like infections, and potential evaluation for a kidney transplant amount (rs.): 32000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 112, 'DOCTOR'],
#      [128, 144, 'HOSPITAL'],
#      [523, 528, 'AMOUNT'],
#      [240, 267, 'CRITICAL ILLNESS COVER'],
#      [292, 323, 'CRITICAL ILLNESS COVER'],
#      [337, 356, 'CASHLESS HOSPITAL COVER'],
#      [366, 395, 'CASHLESS HOSPITAL COVER'],
#      [408, 424, 'CASHLESS HOSPITAL COVER'],
#      [491, 508, 'CRITICAL ILLNESS COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt012213424 date: 12-04-2023 doctor name: dr.swarna hospital name: dgh polonnaruwa description of accident: covid-19 fatality description of claim: policyholder's wife succumbed to complications from covid-19. he now requests reimbursement for funeral expenses, including funeral home services, cremation or burial, urn or casket, and memorial arrangements to cope with her loss. amount (rs.): 16800",
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 109, 'DOCTOR'],
#      [125, 140, 'HOSPITAL'],
#      [452, 457, 'AMOUNT'],
#      [302, 318, 'FUNERAL EXPENSES'],
#      [330, 351, 'FUNERAL EXPENSES'],
#      [353, 362, 'FUNERAL EXPENSES'],
#      [366, 372, 'FUNERAL EXPENSES'],
#      [374, 377, 'FUNERAL EXPENSES'],
#      [381, 387, 'FUNERAL EXPENSES'],
#      [393, 414, 'FUNERAL EXPENSES']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012215344 date: 25-05-2023 doctor name: dr.kapila hospital name: air fors hospital - katunayake description of accident: suffered a heart attack while gardening and passed away description of claim: claiming for the costs of funeral services, cremation, burial, and related expenses. amount (rs.): 36000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 109, 'DOCTOR'],
#      [125, 155, 'HOSPITAL'],
#      [358, 363, 'AMOUNT'],
#      [285, 301, 'FUNERAL EXPENSES'],
#      [303, 312, 'FUNERAL EXPENSES'],
#      [314, 320, 'FUNERAL EXPENSES']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012215628 date: 22-07-2023 doctor name: dr.oushpika hospital name: galle co-op hospital description of accident: accidental fall at home, resulting in hip fracture. description of claim: emergency room visit for assessment and pain management, x-rays to confirm the fracture, hip replacement surgery, hospital stay for up to 5 days for post-operative care, physical therapy to regain mobility and strength, occupational therapy to assist with daily living activities amount (rs.): 25000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 111, 'DOCTOR'],
#      [127, 147, 'HOSPITAL'],
#      [541, 546, 'AMOUNT'],
#      [247, 267, 'CASHLESS HOSPITAL COVER'],
#      [287, 302, 'PERSONAL ACCIDENT COVER'],
#      [304, 310, 'CASHLESS HOSPITAL COVER'],
#      [336, 359, 'CASHLESS HOSPITAL COVER'],
#      [361, 374, 'CASHLESS HOSPITAL COVER'],
#      [396, 415, 'CASHLESS HOSPITAL COVER'],
#      [417, 433, 'CASHLESS HOSPITAL COVER'],
#      [467, 487, 'CASHLESS HOSPITAL COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: lif12218841 date: 25-03-2023 doctor name: dr.deepani hospital name: dgh negombo description of accident: suffered a severe heart attack and required emergency angioplasty and stent placement. description of claim: emergency room fee, intensive care unit (icu) stay for 2 days, angioplasty and stent placement procedure, cardiac rehabilitation program, follow-up appointments with a cardiologist amount (rs.): 30000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 109, 'DOCTOR'],
#      [125, 136, 'HOSPITAL'],
#      [466, 471, 'AMOUNT'],
#      [271, 289, 'CASHLESS HOSPITAL COVER'],
#      [291, 310, 'CASHLESS HOSPITAL COVER'],
#      [312, 315, 'CASHLESS HOSPITAL COVER'],
#      [334, 375, 'CASHLESS HOSPITAL COVER'],
#      [377, 407, 'CRITICAL ILLNESS COVER'],
#      [419, 451, 'CASHLESS HOSPITAL COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt012216234 date: 19-02-2023 doctor name: dr yohan hospital name: ruhunu hospital description of accident: paralysis from meningitis description of claim: hospitalization for doctor's consultations, intensive care and treatment of meningitis, medications to combat the infection, lump-sum payment for home modifications like wheelchair ramps and adapted bathroom facilities, along with long-term care needs like in-home nursing or assisted living amount (rs.): 28100",
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 139, 'HOSPITAL'],
#      [519, 524, 'AMOUNT'],
#      [233, 255, 'CASHLESS HOSPITAL COVER'],
#      [257, 271, 'CASHLESS HOSPITAL COVER'],
#      [276, 299, 'CRITICAL ILLNESS COVER'],
#      [301, 312, 'CRITICAL ILLNESS COVER'],
#      [359, 377, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [383, 399, 'ADDITIONAL ACCIDENT COVER'],
#      [404, 431, 'ADDITIONAL ACCIDENT COVER'],
#      [470, 485, 'CRITICAL ILLNESS COVER'],
#      [489, 504, 'CRITICAL ILLNESS COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012219156 date: 30-09-2023 doctor name: dr.herath hospital name: gh gampaha description of accident: car accident with multiple injuries and extended hospitalization description of claim: i activated my some coverages to cover the immediate expenses of my emergency treatment, icu stay, surgeries, medications, and in-hospital physiotherapy. i am also filing a claim with ambulance transportation, post-discharge physiotherapy sessions, and income loss due to my extended recovery period. amount (rs.): 13000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 109, 'DOCTOR'],
#      [125, 135, 'HOSPITAL'],
#      [563, 568, 'AMOUNT'],
#      [316, 335, 'PERSONAL ACCIDENT COVER'],
#      [337, 345, 'CASHLESS HOSPITAL COVER'],
#      [347, 356, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [358, 369, 'CASHLESS HOSPITAL COVER'],
#      [375, 400, 'CASHLESS HOSPITAL COVER'],
#      [432, 456, 'PERSONAL ACCIDENT COVER'],
#      [473, 495, 'CASHLESS HOSPITAL COVER'],
#      [501, 512, 'FAMILY INCOME BENEFIT']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt012218551 date: 21-03-2023 doctor name: dr.ramya hospital name: lanka hospital description of accident: loss of hearing due to workplace accident description of claim: initial hearing tests, consultations, medical expenses, hearing aids, and disability benefits amount (rs.): 950000',
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 108, 'DOCTOR'],
#      [124, 138, 'HOSPITAL'],
#      [336, 342, 'AMOUNT'],
#      [228, 249, 'CRITICAL ILLNESS COVER'],
#      [251, 264, 'BASIC COVER'],
#      [266, 282, 'CASHLESS HOSPITAL COVER'],
#      [284, 296, 'CRITICAL ILLNESS COVER'],
#      [302, 321, 'PERSONAL ACCIDENT COVER']]}],
#   ['jxg janashakthi group claims action sheet policy number: ngt01231280 date: 08-07-2023 doctor name: dr.hemantha hospital name: hemas hospital description of accident: fell from a ladder while repairing roof, sustaining multiple fractures and a severe head injury. description of claim: to cover initial emergency room expenses, ambulance transport, diagnostic imaging (x-rays, ct scans), 10-day hospital stay, including intensive care unit (icu) costs, surgical procedures to repair fractures, and medications, medical expenses, income loss, and potential permanent disability due to the arm injury. amount (rs.): 5000',
#    {'entities': [[57, 68, 'POLICY_NO'],
#      [75, 85, 'DATE'],
#      [99, 110, 'DOCTOR'],
#      [126, 140, 'HOSPITAL'],
#      [613, 617, 'AMOUNT'],
#      [294, 325, 'CASHLESS HOSPITAL COVER'],
#      [327, 346, 'PERSONAL ACCIDENT COVER'],
#      [348, 366, 'CASHLESS HOSPITAL COVER'],
#      [368, 374, 'CASHLESS HOSPITAL COVER'],
#      [376, 384, 'CASHLESS HOSPITAL COVER'],
#      [394, 407, 'CASHLESS HOSPITAL COVER'],
#      [419, 438, 'CASHLESS HOSPITAL COVER'],
#      [440, 443, 'CASHLESS HOSPITAL COVER'],
#      [452, 471, 'CASHLESS HOSPITAL COVER'],
#      [497, 508, 'CASHLESS HOSPITAL COVER'],
#      [510, 526, 'CASHLESS HOSPITAL COVER'],
#      [528, 539, 'FAMILY INCOME BENEFIT'],
#      [545, 575, 'PERSONAL ACCIDENT COVER']]}],
#   ["jxg janashakthi group claims action sheet policy number: ngt012221080 date: 17-06-2023 doctor name: dr nalinda hospital name: dgh negombo description of accident: emergency appendectomy during a family vacation description of claim: i want to gain my covers to cover the expenses of the appendectomy, including surgeon's fees, operating room charges, hospital stay, medications, and post-operative care. i am also submitting a claim for travel costs associated with my medical emergency, such as additional airfare and hotel accommodations for my family. amount (rs.): 8000",
#    {'entities': [[57, 69, 'POLICY_NO'],
#      [76, 86, 'DATE'],
#      [100, 110, 'DOCTOR'],
#      [126, 137, 'HOSPITAL'],
#      [569, 573, 'AMOUNT'],
#      [311, 325, 'ADDITIONAL CRITICAL ILLNESS COVER'],
#      [327, 349, 'CASHLESS HOSPITAL COVER'],
#      [351, 364, 'CASHLESS HOSPITAL COVER'],
#      [366, 377, 'CASHLESS HOSPITAL COVER'],
#      [383, 402, 'CASHLESS HOSPITAL COVER'],
#      [469, 486, 'PERSONAL ACCIDENT COVER'],
#      [496, 514, 'ADDITIONAL ACCIDENT COVER'],
#      [519, 539, 'ADDITIONAL ACCIDENT COVER']]}]]}

# %%
db = DocBin()

for text, annot in tqdm(train_data['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)

    doc.ents = ents
    db.add(doc)

db.to_disk("/content/drive/MyDrive/4th_Year/DSC4996/Spacy/train_data.spacy")
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 884.57it/s]

# %%
# !python -m spacy init fill-config /content/drive/MyDrive/4th_Year/DSC4996/Spacy/base_config.cfg /content/drive/MyDrive/4th_Year/DSC4996/Spacy/config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive/MyDrive/4th_Year/DSC4996/Spacy/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train /content/drive/MyDrive/4th_Year/DSC4996/Spacy/config.cfg --output /content/drive/MyDrive/4th_Year/DSC4996/Spacy/ --paths.train /content/drive/MyDrive/4th_Year/DSC4996/Spacy/train_data.spacy --paths.dev /content/drive/MyDrive/4th_Year/DSC4996/Spacy/train_data.spacy --gpu-id 0
# Out:
# ℹ Saving to output directory:
# /content/drive/MyDrive/4th_Year/DSC4996/Spacy
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# config.json: 100% 481/481 [00:00<00:00, 2.79MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 2.72MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.88MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 3.29MB/s]
# model.safetensors: 100% 499M/499M [00:01<00:00, 329MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0         349.64    546.48    0.05    0.03    0.19    0.00
#  66     200      169635.20  80782.98   91.01   91.28   90.75    0.91
# 133     400        1267.51   1084.93  100.00  100.00  100.00    1.00
# 200     600         109.25     94.99  100.00  100.00  100.00    1.00
# 266     800          33.56     24.40  100.00  100.00  100.00    1.00
# 333    1000           8.92      9.67  100.00  100.00  100.00    1.00
# 400    1200           5.74      4.69  100.00  100.00  100.00    1.00
# 466    1400          26.20     19.39  100.00  100.00  100.00    1.00
# 533    1600        1154.74    861.22  100.00  100.00  100.00    1.00
# 600    1800          50.06     30.22  100.00  100.00  100.00    1.00
# 666    2000          13.94     10.17  100.00  100.00  100.00    1.00
# ✔ Saved pipeline to output directory
# /content/drive/MyDrive/4th_Year/DSC4996/Spacy/model-last

# %%
nlp_ner = spacy.load("/content/drive/MyDrive/4th_Year/DSC4996/Spacy/model-best")

# %%
input = "JXG JANASHAKTHI GROUP Claims Action Sheet Policy Number: LI4233888 Date: 22-07-2023 Doctor Name: DR.LALITH Hospital Name: RUHUNU HOSPITAL Description of Accident: Paralysis due to a spinal cord injury in a car accident Description of Claim: Claim covers for initial ER treatment, diagnostic tests, ambulance fees, surgery costs, long-term rehabilitation, home modifications Amount (Rs.): 20800"
doc = nlp_ner(input)
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">JXG JANASHAKTHI GROUP Claims Action Sheet Policy Number:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LI4233888
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POLICY_NO</span>
# </mark>
#  Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22-07-2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Doctor Name:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DR.LALITH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DOCTOR</span>
# </mark>
#  Hospital Name:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RUHUNU HOSPITAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HOSPITAL</span>
# </mark>
#  Description of Accident: Paralysis due to a spinal cord injury in a car accident Description of Claim: Claim covers for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     initial ER treatment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASHLESS HOSPITAL COVER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diagnostic tests
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASHLESS HOSPITAL COVER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ambulance fees
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSONAL ACCIDENT COVER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     surgery costs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADDITIONAL CRITICAL ILLNESS COVER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     long-term rehabilitation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRITICAL ILLNESS COVER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     home modifications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSONAL ACCIDENT COVER</span>
# </mark>
#  Amount (Rs.):
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AMOUNT</span>
# </mark>
# </div></span>
